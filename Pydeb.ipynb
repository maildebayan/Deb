# %%
print ("Hello World")
# Out:
# Hello World

# %%
2+2
# Out:
# 4

# %% [markdown]
# 2*3

# %% [markdown]
# Evaluating Basic Arithmetic Expression
# Here you will be evaluating a basic arithmetic expression containing addition and multiplication operations.

# %%
(20+5)*4
# Out:
# 100

# %% [markdown]
# Let us explore Python without coding

# %% [markdown]
# 1+1

# %%
## click after 1+1 in this cell and split it
1+1
2*2
# Out:
# 4

# %%
## click

# %%
Click after 1+1 in this cell and split it
1+1
# Out:
#   Cell In[9], line 1
#     Click after 1+1 in this cell and split it
#           ^
# SyntaxError: invalid syntax

# %%
2*3
# Out:
# 6

# %% [markdown]
# # Debayan Dey

# %% [markdown]
# ## Major Heading

# %% [markdown]
# ### Pushon

# %% [markdown]
# # H1: This is a level 1 Heading
# ## H2: This is a level 2 Heading
# ### H3: This is a level 3 Heading
# #### H4: This is a level 4 Heading
# ##### H5: This is a level 5 Heading
# ###### H6: This is a level 6 Heading

# %% [markdown]
# # H1: This is a level 1 Heading
# ## H2: This is a level 2 Heading
# ### H3: This is a level 3 Heading
# #### H4: This is a level 4 Heading
# ##### H5: This is a level 5 Heading
# ###### H6: This is a level 6 Heading

# %% [markdown]
# # Debayan Dey

# %% [markdown]
# ## Debayan Dey

# %% [markdown]
# ### Debayan Dey

# %% [markdown]
# **Debayan Dey**

# %% [markdown]
# **Debayan Dey**

# %% [markdown]
# __Debayan Dey__

# %% [markdown]
# __Debayan Dey__

# %% [markdown]
# ***Debayan Dey***

# %% [markdown]
# ***Debayan Dey***

# %% [markdown]
# [Skills Network](https://skills.network)

# %% [markdown]
# [Skills Network](https://skills.network)

# %% [markdown]
# [Skills Network](https://skills.network)

# %% [markdown]
# LOGO: ![This is the skills network logo](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png)

# %% [markdown]
# ![Trial](attachment:716a7581-aba6-4bfc-b135-801018112e90.png)

# %% [markdown]
# ![Trial](attachment:716a7581-aba6-4bfc-b135-801018112e90.png)

# %% [markdown]
# ![WhatsApp Image 2024-01-20 at 21.46.56_392db1cb.jpg](attachment:e48a8342-a78f-426c-8af4-500f78f865fc.jpg)

# %% [markdown]
# | Country Name | Capital |
# | -------------| ------ |
# | United States | Washington DC |
# | Australia | Canberra |
# | India | New Delhi |

# %% [markdown]
# | Country Name | Capital |
# | -------------| ------ |
# | United States | Washington DC |
# | Australia | Canberra |
# | India | New Delhi |

# %% [markdown]
# |Name| Age|
# |----| ---|
# |Debayan| 38|
# |Sushmita| 35|
# |Saurav| 41|

# %% [markdown]
# - First item using dashes
# - Second item using dashes
# - Third item using dashes
# - Fourth item using dashes
#
# * First item using asterisks
# * Second item using asterisks
# * Third item using asterisks
# * Fourth item using asterisks
#
# + First item using plus
# + Second item using plus
# + Third item using plus
# + Fourth item using plus

# %% [markdown]
# - First item using dashes
# - Second item using dashes
# - Third item using dashes
# - Fourth item using dashes
#
# * First item using asterisks
# * Second item using asterisks
# * Third item using asterisks
# * Fourth item using asterisks
#
# + First item using plus
# + Second item using plus
# + Third item using plus
# + Fourth item using plus

# %% [markdown]
# - First
# * Second
# + Third

# %% [markdown]
# - First
# * Second
# + Third

# %% [markdown]
# - First
# - Second
# - Third

# %% [markdown]
# * first
# * Second
# * Third

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item

# %% [markdown]
# * First
# * Second
# + Third

# %% [markdown]
# * First
# * Second
# + Third

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Labs_V4/images/Launcher.png)

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Labs_V4/images/Launcher.png)

# %% [markdown]
# [Tools for Data Science](https://www.coursera.org/learn/open-source-tools-for-data-science/home/)

# %% [markdown]
# [Tools for Data Science](https://www.coursera.org/learn/open-source-tools-for-data-science/home/)

# %% [markdown]
# |Fruits | Quantity(Kg)| Price(In Rupee)|
# |-------|-----------|----------------|
# |Apple| 2|500|
# |Orange| 1|200|
# |Mango| 3|1000|
# |Grapes| 2|400|

# %% [markdown]
# |Fruits | Quantity(Kg)| Price(In Rupee)|
# |-------|-----------|----------------|
# |Apple| 2|500|
# |Orange| 1|200|
# |Mango| 3|1000|
# |Grapes| 2|400|

# %% [markdown]
# 1. Python
# 2. Java
# 3. C++
# 4. C

# %% [markdown]
# 1. Python
# 2. Java
# 3. C++
# 4. C

# %%
11+4
# Out:
# 15

# %%
150*50
# Out:
# 7500

# %%
150*50
# Out:
# 7500

# %%
6*8
# Out:
# 48
